# %%
# So here i am basically just testing out the swing traj and the ik solver, to see if they work together. I will eventually use this to test out the whole system, but for now i just want to make sure the basics are working.
# But then for updating the new swing update to stance, i'll probably need a full ik solver, rather than just a step solver
# Trying: p(t) = [x0 + A*sin(w*t)]
#                [y0]
#                [z0 + H max(0, sin(w*t))]
class StaticModel:
    """A static model of the robot, used for kinematics and trajectory planning."""
    
    def __init__(self, chain: ChainParams, T0_base: Matrix):
        self.chain = chain
        self.T0_base = T0_base
